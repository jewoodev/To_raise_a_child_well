# %%
import pandas as pd
import numpy as np


df = pd.read_excel('GNP_in_each_region.xlsx')
df
# Out:
# c:\Users\PlayData\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         시도별        2006     2006.1    2006.2    2006.3        2007     2007.1  \
# 0       시도별  1인당 지역내총생산  1인당 지역총소득  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  1인당 지역총소득
# 1        전국       20878      20817     12058     11074       22456      22399
# 2     서울특별시       24420      27315     14008     13497       26478      30371
# 3     부산광역시       15386      16272     11323     10441       16703      17592
# 4     대구광역시       13580      15228     11193     10681       14558      15885
# 5     인천광역시       18838      18100     10769     10083       20455      19729
# 6     광주광역시       14938      15846     11389     10559       16116      17373
# 7     대전광역시       15657      17010     11755     10847       16513      17867
# ...

# %%
# df = df.reset_index(drop=True)

# %%
df1.columns[-1]
# Out:
# '2021 p)'

# %%
df1 = df.iloc[1:, 1:66:4]
df1.index = df['시도별'][1:]

# %%
df1.to_excel('After_preprocessing/GNP_in_each_region.xlsx')
