# %% [markdown]
# # 모든 데이터 불러오기

# %%
import pandas as pd
import numpy as np

fluctuation_rate_of_land_price = pd.read_excel('After_preprocessing/fluctuation_rate_of_land_price_v2.xlsx')
Deposit_of_the_bank_of_deposit = pd.read_excel('After_preprocessing/Deposit_of_the_bank_of_deposit.xlsx', index_col='Unnamed: 0')
Labor_Force_Participation_Rate = pd.read_excel('After_preprocessing/Labor_Force_Participation_Rate.xlsx')

# %% [markdown]
# ## 전국 DataFrame

# %% [markdown]
# ### 지가변동률

# %%
fluctuation_rate_of_land_price
# Out:
#     Unnamed: 0     전국  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  \
# 0   2005-01-01  0.157  0.173  0.038  0.168  0.140  0.082  0.134  0.063
# 1   2005-02-01  0.123  0.117  0.032  0.190  0.154  0.044  0.120  0.101
# 2   2005-03-01  0.278  0.375  0.051  0.239  0.358  0.044  0.405  0.128
# 3   2005-04-01  0.455  0.672  0.042  0.210  0.557  0.039  0.438  0.110
# 4   2005-05-01  0.434  0.549  0.072  0.218  0.513  0.102  0.521  0.112
# ..         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 199 2021-08-01  0.395  0.434  0.423  0.417  0.397  0.275  0.343  0.218
# 200 2021-09-01  0.396  0.439  0.411  0.388  0.439  0.279  0.384  0.214
# 201 2021-10-01  0.372  0.426  0.347  0.354  0.363  0.249  0.372  0.241
# 202 2021-11-01  0.367  0.419  0.285  0.325  0.372  0.257  0.366  0.326
# 203 2021-12-01  0.357  0.409  0.298  0.382  0.379  0.258  0.398  0.209
#
#     세종특별자치시    경기도    강원도   충청북도   충청남도   전라북도   전라남도   경상북도   경상남도 제주특별자치도
# ...

# %%
fluctuation_rate_of_land_price = fluctuation_rate_of_land_price.iloc[12:]

# %%
fluctuation_rate_of_land_price.iloc[:, 1]
# Out:
# 12     0.295
# 13     0.386
# 14     0.541
# 15     0.519
# 16     0.517
#        ...
# 199    0.395
# 200    0.396
# 201    0.372
# 202    0.367
# 203    0.357
# Name: 전국, Length: 192, dtype: float64

# %%
The_whole_country = pd.DataFrame(data=fluctuation_rate_of_land_price.iloc[:, 1], )

# %%
The_whole_country.index = fluctuation_rate_of_land_price['Unnamed: 0']

# %%
The_whole_country.index.name = None
The_whole_country.columns= ["지가변동률"]

# %% [markdown]
# ### 예금은행 예금액

# %%
Dtbd_twc = pd.DataFrame(Deposit_of_the_bank_of_deposit.iloc[:192, 0])
Dtbd_twc
# Out:
#                    전국
# 2006-01-01   545065.9
# 2006-02-01   553445.2
# 2006-03-01   548811.4
# 2006-04-01   551235.9
# 2006-05-01   557260.7
# ...               ...
# 2021-08-01  1806536.3
# 2021-09-01  1824689.3
# 2021-10-01  1829403.9
# 2021-11-01  1842285.6
# 2021-12-01  1869023.7
#
# [192 rows x 1 columns]

# %%
Dtbd_twc.columns= ["예금은행 예금액"]

# %%
The_whole_country = pd.concat([The_whole_country, Dtbd_twc], axis=1)

# %% [markdown]
# ## 여성 경제참여율

# %%
Labor_Force_Participation_Rate
# Out:
#      Unnamed: 0     계  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  \
# 0       1999.06  49.0   48.7   46.5   46.7   46.8   44.4   42.6   41.5
# 1       1999.07  48.7   48.9   47.0   45.9   46.0   45.5   42.9   40.6
# 2       1999.08  48.1   47.6   46.4   45.4   45.7   44.4   42.8   40.6
# 3       1999.09  49.2   48.5   47.7   47.5   47.0   45.4   43.9   41.6
# 4       1999.10  49.5   48.5   47.5   48.8   46.7   45.3   45.0   40.7
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...
# 279     2022.09  55.1   55.0   50.2   52.5   55.9   52.1   53.6   49.1
# 280     2022.10  55.0   54.5   50.3   51.9   55.9   52.8   54.0   49.4
# 281     2022.11  55.1   54.9   50.5   51.8   56.9   52.7   54.3   49.5
# 282     2022.12  54.2   55.2   50.9   51.7   56.4   51.5   54.7   49.0
# 283     2023.01  53.6   55.0   50.4   51.4   55.2   52.2   54.4   48.8
#
#     세종특별자치시   경기도   강원도  충청북도  충청남도  전라북도  전라남도  경상북도  경상남도   제주도
# ...

# %%
Labor_Force_Participation_Rate.index.name = None
Labor_Force_Participation_Rate.columns = ["", '계', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',\
    '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
    '경상북도', '경상남도', '제주도']

# %%
Labor_Force_Participation_Rate.iloc[268,0]
# Out:
# 2021.1

# %%
lfpr = pd.DataFrame(Labor_Force_Participation_Rate.iloc[79:271, 1])

# %%
lfpr.index = Labor_Force_Participation_Rate.iloc[:, 0][79:271]

# %%
lfpr.columns = ["여성 경제참여율"]

# %% [markdown]
# # 10월이 1로 찍혀서 전처리 필요

# %%
for i in range(9, 192, 12):
    lfpr.apply(lambda x: x.index[i].split('.')[1] = 10)
# Out:
#   File "C:\Users\PlayData\AppData\Local\Temp\ipykernel_2620\204884197.py", line 2
#     lfpr.apply(lambda x: x.index[i].split('.')[1] = 10)
#                ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
lfpr.index[9].split('.')[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2620\3637452598.py in <module>
# ----> 1 lfpr.index[9].split('.')[1]
#
# AttributeError: 'numpy.float64' object has no attribute 'split'
