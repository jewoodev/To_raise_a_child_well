# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('financial_independer_rate.csv', encoding='CP949')

# %%
df['행정구역별(1)'][1:]
# Out:
# 1          전국
# 2       서울특별시
# 3       부산광역시
# 4       대구광역시
# 5       인천광역시
# 6       광주광역시
# 7       대전광역시
# 8       울산광역시
# 9     세종특별자치시
# 10        경기도
# 11        강원도
# 12       충청북도
# 13       충청남도
# 14       전라북도
# 15       전라남도
# 16       경상북도
# 17       경상남도
# 18    제주특별자치도
# Name: 행정구역별(1), dtype: object

# %%
df1 = df.iloc[1:, 1:]
df1.index = df['행정구역별(1)'][1:]
df1.drop(['2014.1', '2015.1', '2016.1', '2017.1', '2018.1', '2019.1', '2020.1', '2021.1', '2022', '2022.1'], axis=1, inplace=True)
df1
# Out:
#           2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 행정구역별(1)
# 전국        54.4  53.6  53.9  53.6  52.2  51.9  52.3  51.1  50.3  50.6  52.5
# 서울특별시     94.3  90.5  88.3  92.0  85.8  90.3  90.2  88.8  84.2  84.3  84.7
# 부산광역시     70.2  62.9  60.5  58.3  57.6  56.4  57.4  56.6  57.4  56.8  60.1
# 대구광역시     70.7  63.9  59.5  54.7  56.3  53.5  52.8  51.8  51.7  53.1  57.1
# 인천광역시     69.2  69.8  71.0  74.2  70.4  69.3  71.0  67.3  66.9  64.4  67.0
# 광주광역시     57.5  54.2  52.6  48.3  47.5  47.5  46.6  45.4  46.0  49.3  51.5
# 대전광역시     72.8  72.1  66.4  59.3  56.3  57.2  58.3  57.5  54.9  54.9  55.0
# 울산광역시     65.7  68.4  69.9  67.7  67.2  69.1  71.2  70.7  70.2  72.0  72.2
# 세종특별자치시      -     -     -     -     -     -     -  38.8  50.6  54.8  59.0
# 경기도       75.2  74.9  76.3  75.9  72.8  72.5  72.6  71.6  67.7  66.6  67.4
# 강원도       26.7  28.3  28.2  28.0  27.1  27.5  26.9  26.6  26.6  25.9  27.1
# ...

# %%
df1.to_excel('After_preprocessing/financial_independer_rate.xlsx')
