# %%
# 라이브러리
import numpy as np
import pandas as pd
import datetime as dt

# %%
path = "dataset/"
dohee_path = "../dohee/"
jewoo_path = "../jewoo/After_preprocessing"

# %%
# 파일불러오기
elder_df = pd.read_excel(path+'고령화인구비율최종.xlsx',index_col=0)
fn_idp_df= pd.read_excel(path+'이혼건수최종.xlsx',index_col=0)
Unemp_df=pd.read_excel(path+'실업률최종.xlsx',index_col=0)
Married_df=pd.read_excel(path+'혼인건수최종.xlsx',index_col=0)
CPI_df=pd.read_excel(path+'소비자물가지수최종.xlsx',index_col=0)
girl=pd.read_excel(path+'행정구역여성인구수최종.xlsx',index_col=0)
number_of_birth = pd.read_excel(dohee_path+'1997-2021_총_출생아수.xlsx',index_col=0)
apart_price = pd.read_excel(dohee_path+'2003-2022_아파트전세_가격지수.xlsx',index_col=0)
unsold_df = pd.read_excel(dohee_path+'2003-2022_아파트전세_가격지수.xlsx',index_col=0)
bank_deposit_df = pd.read_excel(jewoo_path+'/Deposit_of_the_bank_of_deposit.xlsx',index_col=0)
fn_idp_df = pd.read_excel(jewoo_path+'/Labor_Force_Participation_Rate.xlsx',index_col=0) # 계, 제주도
fluct_df = pd.read_excel(jewoo_path+'/fluctuation_rate_of_land_price_v2.xlsx',index_col=0)

# %%
# 1997~2021합치기
girl_df = girl.loc[:'2021-12-01']
number_of_birth_df = number_of_birth.loc['2008-01-01':'2021-12-01']
number_of_birth_df
# Out:
#                전국  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  세종특별자치시  \
# 2008-01-01  46747   9630   2615   2075   2417   1450   1562   1075        0
# 2008-02-01  39495   8097   2174   1765   2074   1212   1226    929        0
# 2008-03-01  41318   8411   2387   1804   2328   1240   1255    999        0
# 2008-04-01  38783   7861   2224   1799   2149   1122   1253    962        0
# 2008-05-01  37598   7628   2130   1657   2086   1087   1233    904        0
# ...           ...    ...    ...    ...    ...    ...    ...    ...      ...
# 2021-08-01  22282   3858   1302    950   1272    671    593    527      290
# 2021-09-01  21905   3753   1238    893   1320    707    626    513      305
# 2021-10-01  20749   3533   1183    890   1240    604    592    505      319
# 2021-11-01  19829   3513   1043    792   1189    661    560    451      263
# 2021-12-01  17179   3034    888    685    959    474    509    404      226
#
#               경기도   강원도  충청북도  충청남도  전라북도  전라남도  경상북도  경상남도  제주특별자치도
# 2008-01-01  12005  1275  1410  1941  1700  1698  2318  3033      543
# 2008-02-01  10234  1079  1190  1707  1344  1395  1968  2636      465
# 2008-03-01  10531  1130  1275  1670  1391  1503  2151  2740      503
# 2008-04-01   9878   956  1140  1631  1352  1348  2034  2660      414
# 2008-05-01   9710   961  1110  1682  1290  1294  1908  2493      425
# ...           ...   ...   ...   ...   ...   ...   ...   ...      ...
# 2021-08-01   6473   649   747   943   610   738  1065  1322      272
# 2021-09-01   6347   594   649   949   628   708  1001  1334      340
# 2021-10-01   6105   618   668   815   588   632   889  1238      330
# 2021-11-01   5766   587   631   840   543   640   961  1135      254
# 2021-12-01   5210   482   560   717   524   542   775   975      215
#
# [168 rows x 18 columns]

# %%
# 총 출산아 수 /15~49세 여성의 수
birth_rate_df = girl_df.copy()
birth_rate_df = number_of_birth_df/birth_rate_df
# 경제참가전처리
fn_idp_df.rename(columns={'계':'전국','제주도':'제주특별자치도'},inplace=True)
fn_idp_df.index.name = '시점'
fn_idp_df.reset_index(inplace=True)
fn_idp_df['시점'] = fn_idp_df['시점'].astype('str')
fn_idp_df['시점'] = fn_idp_df['시점'].apply(lambda x: x+'0' if len(x)==6 else x)
fn_idp_df.set_index('시점',inplace=True)
fn_idp_df.index = pd.to_datetime(fn_idp_df.index, format='%Y-%m')

# %%
# 서울데이터프레임
seoul_df = pd.DataFrame()

# %%
bank_deposit_df.replace('-',0,inplace=True)
bank_deposit_df = bank_deposit_df.apply(pd.to_numeric)
bank_deposit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 203 entries, 2006-01-01 to 2022-11-01
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   전국       203 non-null    float64
#  1   서울특별시    203 non-null    float64
#  2   부산광역시    203 non-null    float64
#  3   대구광역시    203 non-null    float64
#  4   인천광역시    203 non-null    float64
#  5   광주광역시    203 non-null    float64
#  6   대전광역시    203 non-null    float64
#  7   울산광역시    203 non-null    float64
#  8   세종특별자치시  203 non-null    float64
#  9   경기도      203 non-null    float64
#  10  강원도      203 non-null    float64
#  11  충청북도     203 non-null    float64
#  12  충청남도     203 non-null    float64
#  13  전라북도     203 non-null    float64
#  14  전라남도     203 non-null    float64
#  15  경상북도     203 non-null    float64
#  16  경상남도     203 non-null    float64
#  17  제주특별자치도  203 non-null    float64
# dtypes: float64(18)
# memory usage: 30.1 KB

# %%
# 파일 리스트
file_list = [Unemp_df, fn_idp_df, elder_df, Married_df, CPI_df, birth_rate_df, apart_price, unsold_df, bank_deposit_df,fn_idp_df ,fluct_df]

# %%
# 파일 리스트에서 전국 데이터만 가져오기
k = 0
for i in file_list:
    k = k + 1
    seoul_df[k]= i['서울특별시']

# %%
# 이혼건수와 혼인건수는 22년도 데이터가 없음, 1999.06~2023-01까지
seoul_df.columns = ['실업률','이혼율','고령화비율','혼인건수','소비자물가지수','출산아수/가임기여성의수','아파트전세지수','미분양주택지수','은행예금지수','경제활동참가율','지가변동률']
seoul_df['이혼율'] = seoul_df['이혼율'].values / seoul_df['혼인건수']
seoul_df
# Out:
#             실업률       이혼율  고령화비율    혼인건수  소비자물가지수  출산아수/가임기여성의수  아파트전세지수  \
# 시점
# 1999-06-01  5.5  0.005421    NaN  8983.0   59.841           NaN      NaN
# 1999-07-01  6.1  0.007783    NaN  6283.0   59.688           NaN      NaN
# 1999-08-01  5.0  0.009952    NaN  4783.0   60.354           NaN      NaN
# 1999-09-01  4.2  0.011844    NaN  4095.0   60.456           NaN      NaN
# 1999-10-01  4.2  0.008017    NaN  6050.0   60.969           NaN      NaN
# ...         ...       ...    ...     ...      ...           ...      ...
# 2022-09-01  3.0       NaN   17.4     NaN  107.850           NaN    102.1
# 2022-10-01  3.0       NaN   17.4     NaN  108.160           NaN    100.6
# 2022-11-01  3.0       NaN   17.5     NaN  108.030           NaN     97.7
# 2022-12-01  2.7       NaN   17.6     NaN  108.470           NaN     93.0
# 2023-01-01  3.9       NaN   17.7     NaN  109.300           NaN      NaN
#
#             미분양주택지수     은행예금지수  경제활동참가율  지가변동률
# 시점
# 1999-06-01      NaN        NaN     48.7    NaN
# 1999-07-01      NaN        NaN     48.9    NaN
# 1999-08-01      NaN        NaN     47.6    NaN
# 1999-09-01      NaN        NaN     48.5    NaN
# 1999-10-01      NaN        NaN     48.5    NaN
# ...             ...        ...      ...    ...
# 2022-09-01    102.1  1041342.5     55.0    NaN
# 2022-10-01    100.6  1043267.0     54.5    NaN
# 2022-11-01     97.7  1044334.0     54.9    NaN
# 2022-12-01     93.0        NaN     55.2    NaN
# 2023-01-01      NaN        NaN     55.0    NaN
#
# [284 rows x 11 columns]

# %%
seoul_df.describe()
# Out:
#               실업률         이혼율       고령화비율          혼인건수     소비자물가지수  \
# count  284.000000  271.000000  181.000000    271.000000  284.000000
# mean     4.083451    0.010188   12.535912   5497.154982   85.007634
# std      0.776629    0.002933    2.714382   1449.414655   13.557327
# min      2.500000    0.004548    8.300000   2698.000000   59.688000
# 25%      3.600000    0.008499   10.100000   4588.000000   73.730500
# 50%      4.000000    0.009625   12.400000   5396.000000   87.843500
# 75%      4.500000    0.011564   14.700000   6109.000000   97.199000
# max      7.300000    0.020126   17.700000  10730.000000  109.300000
#
#        출산아수/가임기여성의수     아파트전세지수     미분양주택지수        은행예금지수    경제활동참가율  \
# count    168.000000  230.000000  230.000000  2.030000e+02  284.00000
# mean       0.002296   72.979130   72.979130  5.783334e+05   52.25669
# std        0.000449   19.285454   19.285454  2.092717e+05    1.83162
# min        0.001267   43.800000   43.800000  2.713104e+05   47.60000
# 25%        0.001896   53.725000   53.725000  4.371203e+05   50.90000
# 50%        0.002423   70.850000   70.850000  5.455764e+05   52.50000
# 75%        0.002616   91.575000   91.575000  6.852878e+05   53.60000
# max        0.003278  103.500000  103.500000  1.044334e+06   55.40000
#
#             지가변동률
# count  204.000000
# mean     0.283828
# std      0.426988
# min     -3.490000
# 25%      0.180000
# 50%      0.316500
# 75%      0.449500
# max      1.234000

# %%
seoul_df.to_excel(path+'서울시출산율모델.xlsx')
