# %%
# 라이브러리
import pandas as pd
import numpy as np

# %%
# 기본 경로 설정
path = 'C:/Users/gihun/Python_data/data/Fertility_rate'

# %%
# 서울시 출산율 데이터 불러오기
seoul_target_df = pd.read_excel(path+'/서울시출산율.xlsx')

# %%
# 서울시 출산율 데이터프레임 전처리
seoul_target_df = seoul_target_df.set_index('시점')
seoul_target_df
# Out:
# c:\Users\gihun\Python_Data\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         종로구    성동구    광진구    강북구    노원구    구로구   영등포구    관악구    강남구    강동구
# 시점
# 시점    합계출산율  합계출산율  합계출산율  합계출산율  합계출산율  합계출산율  합계출산율  합계출산율  합계출산율  합계출산율
# 2006  0.811  1.035  0.945  0.886  1.114  1.156  1.101  0.922  0.797  0.993
# 2007  0.879  1.154  0.991  1.032   1.21  1.232  1.208  1.005  0.877  1.073
# 2008  0.857  1.091  0.939  0.971  1.134  1.202  1.116  0.942  0.823  1.008
# 2009  0.796  0.971  0.891  0.971  1.046  1.124  1.056  0.879  0.785  1.028
# 2010  0.837  1.029  0.935  0.996    1.1  1.197  1.128  0.881  0.862  1.096
# 2011   0.86  1.026    0.9  1.018  1.083  1.177  1.103  0.897  0.855  1.104
# 2012   0.89  1.077  0.957  1.051  1.162  1.258  1.142  0.891  0.886  1.101
# ...
